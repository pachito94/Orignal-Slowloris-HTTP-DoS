# %% [markdown]
# # ✔ Conocimientos Previos
#  Que debemos saber
# *   Que es un Programa
# *   como escribir instrucciones en python
# *   Que es una Variables

# %% [markdown]
# ## Tipos de Datos en Python
#
# Que debes saber
# * Diferencia entre umeros, textos, listas, boleanos

# %%
#Ejemplos
entero = 10
decimal=10.3
texto="coco"
lista1=[1,2,3,4]
bandera =True
bandera =False
dicionario={"nombre":"francisco prado"}
#Tipos de Dato
print(type(entero))
print(type(decimal))
print(type(texto))
print(type(lista1))
print(type(bandera))
print(type(dicionario))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# <class 'bool'>
# <class 'dict'>

# %% [markdown]
# 🧮Operaciones Matematicas y logicas
# * operaciones basicas: +, -, *, /, **, %, //
# * comparaciones: >, <, >=, <=, ==, ¡=
# * condiciones if y else

# %%
#Ejemplo Operaciones basicas +
n1=16
n2=25
suma=n1+n2
print(suma)
# Out:
# 41

# %%
#Ejemplo Operaciones basicas -
n1=16
n2=25
resta=n1-n2
print(resta)
# Out:
# -9

# %%
#Ejemplo Operaciones basicas *
n1=16
n2=25
mult=n1*n2
print(mult)
# Out:
# 400

# %%
#Ejemplo Operaciones basicas /
n1=16
n2=25
div=n1/n2
print(div)
# Out:
# 0.64

# %%
#Ejemplo Operaciones basicas **
n1=16
n2=25
exp=n1**n2
print(exp)
# Out:
# 1267650600228229401496703205376

# %%
#Ejemplo Operaciones basicas %
n1=16
n2=25
modulo=n1%n2
print(modulo)
# Out:
# 16

# %%
#Ejemplo Operaciones basicas //
n1=16
n2=25
modulo=n1//n2
print(modulo)
# Out:
# 0

# %%
#Ejemplo Comparaciones >
n1=16
n2=25
comp=n1>n2
print(comp)
# Out:
# False

# %%
#Ejemplo Comparaciones <
n1=16
n2=25
comp=n1<n2
print(comp)
# Out:
# True

# %%
#Ejemplo Comparaciones >=
n1=16
n2=25
comp=n1>=n2
print(comp)
# Out:
# False

# %%
#Ejemplo Comparaciones <=
n1=16
n2=25
comp=n1<=n2
print(comp)
# Out:
# True

# %%
#Ejemplo Comparaciones ¡= diferente
n1=16
n2=25
comp=n1!=n2
print(comp)
# Out:
# True

# %%
#Ejemplo Comparaciones ==
n1=16
n2=25
comp=n1==n2
print(comp)
# Out:
# False

# %%
#ejemplo
edad = 16
if edad >= 18:
  print("eres mayor de edad")
else:
  print("eres menor de edad")
# Out:
# eres menor de edad

# %% [markdown]
# ### Estructuras de repeticion
# Que deben saber:
# *uso for y while

# %%
#Ejemplo for
for i in range(5):
   print("numero  ",i)
# Out:
# numero   0
# numero   1
# numero   2
# numero   3
# numero   4

# %%
#ejemplo while
contador=1
while contador<=5:
  print("numero  ",contador)
  contador=contador+1
# Out:
# numero   1
# numero   2
# numero   3
# numero   4
# numero   5

# %% [markdown]
# #Introduccion a las liberias de python
#  Que deben saber: que es y como se importa

# %%
import math
numero=16
print("raiz cuadrada  ",math.sqrt(numero))
# Out:
# raiz cuadrada   4.0
